# %%
import matplotlib.pyplot as plt

plt.plot(range(1,6), [1461.51,928.05, 501.76,552.44, 477.92])
plt.axis([1, 5, 0, 2000])
plt.xlabel('number of instances')
plt.ylabel('time used for a 10-epoches training')
plt.show()
